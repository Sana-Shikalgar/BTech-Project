# %% [markdown]
# ### IMPORTING IMPORTANT LIBRARIES

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !c:\users\ajay\documents\sana\env\scripts\python.exe -m pip install --upgrade pip
# !pip install torch
# !pip install torchvision
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install scikit-learn
# !pip install seaborn
# !pip install tabulate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
# torch.__version__
from torchvision import datasets, transforms, models  # datsets  , transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
from datetime import datetime
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

# %%
torch.cuda.empty_cache()
torch.no_grad()
torch.cuda.synchronize()
# !python3 --version
# Out:
# Python 3.8.10

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# <b> Dataset Link (Plant Vliiage Dataset ):</b><br> <a href='https://data.mendeley.com/datasets/tywbtsjrjv/1'> https://data.mendeley.com/datasets/tywbtsjrjv/1 </a>

# %%
transform = transforms.Compose(
    [transforms.Resize(255), transforms.CenterCrop(224), transforms.ToTensor()]
)

# %%
# The the link to where you have stored the dataset.
dataset = datasets.ImageFolder("../../All_Datasets/PlantVillage (Balanced Category wise)", transform=transform)

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 78000
#     Root location: ../../All_Datasets/PlantVillage (Balanced Category wise)
#     StandardTransform
# Transform: Compose(
#                Resize(size=255, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#            )

# %% [markdown]
# ### Validation

# %%
# Suppose your dataset has integer class labels in dataset.targets
y = np.array(dataset.targets)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# --- Step 1: Create train+val vs. test (90% / 10%)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.10, random_state=42)
train_val_indices, test_indices = next(sss1.split(np.zeros(len(y)), y))

# %%
# --- Step 2: From train+val, split into train vs. validation
#  (We want validation to be 10% of the whole dataset, which is 1/9 of train+val)
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.1111, random_state=42)
y_train_val = y[train_val_indices]
train_indices_sub, val_indices_sub = next(sss2.split(np.zeros(len(y_train_val)), y_train_val))

# %%
# Convert the local indices back to the original dataset’s indexing
train_indices = train_val_indices[train_indices_sub]
val_indices   = train_val_indices[val_indices_sub]

# %% [markdown]
# ### Split into Train and Test

# %%
# Create samplers
train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)
test_sampler = SubsetRandomSampler(test_indices)

# %%
print("Train size:", len(train_indices))
print("Validation size:", len(val_indices))
print("Test size:", len(test_indices))
# Out:
# Train size: 62400
# Validation size: 7800
# Test size: 7800

# %%
targets_size = len(dataset.class_to_idx)
print(targets_size)
# Out:
# 39

# %% [markdown]
# ### Pre-trained EfficientNet-B0

# %%
class EfficientNetB0_Model(nn.Module):
    def __init__(self, K):
        super(EfficientNetB0_Model, self).__init__()
        self.model = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)

        # Modify final classification layer
        in_features = self.model.classifier[1].in_features
        self.model.classifier[1] = nn.Linear(in_features, K)

    def forward(self, x):
        return self.model(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
model = EfficientNetB0_Model(targets_size).to(device)

# %%
model.to(device)
# Out:
# EfficientNetB0_Model(
#   (model): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#         )
#       )
#       (3): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#         )
#       )
#       (5): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#         )
#       )
#       (7): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#         )
#       )
#       (8): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=True)
#       (1): Linear(in_features=1280, out_features=39, bias=True)
#     )
#   )
# )

# %%
# !pip install torchsummary
from torchsummary import summary

summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#               SiLU-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112
[-1, 1152, 7, 7]         221,184
#      BatchNorm2d-204           [-1, 1152, 7, 7]           2,304
#             SiLU-205           [-1, 1152, 7, 7]               0
#           Conv2d-206           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-207           [-1, 1152, 7, 7]           2,304
#             SiLU-208           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-209           [-1, 1152, 1, 1]               0
#           Conv2d-210             [-1, 48, 1, 1]          55,344
#             SiLU-211             [-1, 48, 1, 1]               0
#           Conv2d-212           [-1, 1152, 1, 1]          56,448
#          Sigmoid-213           [-1, 1152, 1, 1]               0
# SqueezeExcitation-214           [-1, 1152, 7, 7]               0
#           Conv2d-215            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-216            [-1, 192, 7, 7]             384
#  StochasticDepth-217            [-1, 192, 7, 7]               0
#           MBConv-218            [-1, 192, 7, 7]               0
#           Conv2d-219           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-220           [-1, 1152, 7, 7]           2,304
#             SiLU-221           [-1, 1152, 7, 7]               0
#           Conv2d-222           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-223           [-1, 1152, 7, 7]           2,304
#             SiLU-224           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-225           [-1, 1152, 1, 1]               0
#           Conv2d-226             [-1, 48, 1, 1]          55,344
#             SiLU-227             [-1, 48, 1, 1]               0
#           Conv2d-228           [-1, 1152, 1, 1]          56,448
#          Sigmoid-229           [-1, 1152, 1, 1]               0
# SqueezeExcitation-230           [-1, 1152, 7, 7]               0
#           Conv2d-231            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-232            [-1, 192, 7, 7]             384
#  StochasticDepth-233            [-1, 192, 7, 7]               0
#           MBConv-234            [-1, 192, 7, 7]               0
#           Conv2d-235           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-236           [-1, 1152, 7, 7]           2,304
#             SiLU-237           [-1, 1152, 7, 7]               0
#           Conv2d-238           [-1, 1152, 7, 7]          10,368
#      BatchNorm2d-239           [-1, 1152, 7, 7]           2,304
#             SiLU-240           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-241           [-1, 1152, 1, 1]               0
#           Conv2d-242             [-1, 48, 1, 1]          55,344
#             SiLU-243             [-1, 48, 1, 1]               0
#           Conv2d-244           [-1, 1152, 1, 1]          56,448
#          Sigmoid-245           [-1, 1152, 1, 1]               0
# SqueezeExcitation-246           [-1, 1152, 7, 7]               0
#           Conv2d-247            [-1, 320, 7, 7]         368,640
#      BatchNorm2d-248            [-1, 320, 7, 7]             640
#           MBConv-249            [-1, 320, 7, 7]               0
#           Conv2d-250           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-251           [-1, 1280, 7, 7]           2,560
#             SiLU-252           [-1, 1280, 7, 7]               0
# AdaptiveAvgPool2d-253           [-1, 1280, 1, 1]               0
#          Dropout-254                 [-1, 1280]               0
#           Linear-255                   [-1, 39]          49,959
#     EfficientNet-256                   [-1, 39]               0
# ================================================================
# Total params: 4,057,507
# Trainable params: 4,057,507
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 173.65
# Params size (MB): 15.48
# Estimated Total Size (MB): 189.70
# ----------------------------------------------------------------

# %% [markdown]
# ### Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0001):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0

    def step(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
            return False  # Do not stop
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True   # Stop training
            return False

early_stopping = EarlyStopping(patience=5, min_delta=0.0001)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# %%
# Cosine Annealing LR Scheduler
# The learning rate resets every 10 epochs, allowing the model to explore different solutions.
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

current_lr = scheduler.get_last_lr()[0]  # gets the learning rate from the first param group
print(f"Current Learning Rate: {current_lr}")
# Out:
# Current Learning Rate: 0.0001

# %% [markdown]
# ### Batch Gradient Descent / Training Model

# %%
def batch_gd(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        t0 = datetime.now()

        # --- Training Phase ---
        model.train()  # Set model to training mode
        running_train_loss = 0.0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()              # Clear gradients from the previous step
            outputs = model(inputs)            # Forward pass
            loss = criterion(outputs, targets) # Compute loss
            loss.backward()                    # Backpropagation
            optimizer.step()                   # Update parameters
            running_train_loss += loss.item()

        avg_train_loss = running_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # --- Validation Phase ---
        model.eval()  # Set model to evaluation mode
        running_val_loss = 0.0

        # Disable gradient computation for validation
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                running_val_loss += loss.item()

        avg_val_loss = running_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        # Step the scheduler based on the validation loss
        scheduler.step()

        # Print epoch statistics
        duration = datetime.now() - t0
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_train_loss:.3f}, Val Loss: {avg_val_loss:.3f}, Duration: {duration}")

        # --- Early Stopping Check ---
        if early_stopping.step(avg_val_loss):
            stopping_epoch = epoch + 1
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    return train_losses, val_losses

# %%
batch_size = 16
train_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=train_sampler, num_workers=2, pin_memory=True
)
test_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=test_sampler, num_workers=2, pin_memory=True
)
validation_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=val_sampler, num_workers=2, pin_memory=True
)
# train_dataset, val_dataset, test_dataset

# %%
number_of_epoch = 50
train_losses, validation_losses = batch_gd(
    model, criterion, optimizer, scheduler, train_loader, validation_loader, number_of_epoch
)
# Out:
# Epoch 1/50 - Train Loss: 0.954, Val Loss: 0.733, Duration: 0:08:33.785732
# Epoch 2/50 - Train Loss: 0.744, Val Loss: 0.714, Duration: 0:06:51.124366
# Epoch 3/50 - Train Loss: 0.721, Val Loss: 0.704, Duration: 0:06:48.315334
# Epoch 4/50 - Train Loss: 0.708, Val Loss: 0.700, Duration: 0:06:47.685085
# Epoch 5/50 - Train Loss: 0.698, Val Loss: 0.696, Duration: 0:06:49.318317
# Epoch 6/50 - Train Loss: 0.694, Val Loss: 0.691, Duration: 0:07:00.687517
# Epoch 7/50 - Train Loss: 0.689, Val Loss: 0.690, Duration: 0:06:48.473426
# Epoch 8/50 - Train Loss: 0.688, Val Loss: 0.687, Duration: 0:06:48.565885
# Epoch 9/50 - Train Loss: 0.685, Val Loss: 0.685, Duration: 0:06:48.136131
# Epoch 10/50 - Train Loss: 0.684, Val Loss: 0.684, Duration: 0:06:46.222192
# Epoch 11/50 - Train Loss: 0.685, Val Loss: 0.684, Duration: 0:06:50.703613
# Epoch 12/50 - Train Loss: 0.684, Val Loss: 0.683, Duration: 0:06:48.236924
# Epoch 13/50 - Train Loss: 0.684, Val Loss: 0.684, Duration: 0:06:48.537541
# Epoch 14/50 - Train Loss: 0.684, Val Loss: 0.686, Duration: 0:06:48.274177
# Epoch 15/50 - Train Loss: 0.685, Val Loss: 0.687, Duration: 0:06:53.202773
# Epoch 16/50 - Train Loss: 0.686, Val Loss: 0.691, Duration: 0:06:45.769930
# Epoch 17/50 - Train Loss: 0.687, Val Loss: 0.686, Duration: 0:06:47.842567
# Early stopping triggered at epoch 17

# %% [markdown]
# ### Save the Model

# %%
# After training your model:
current_epoch = len(train_losses) 
checkpoint = {
    'model_state_dict': model.state_dict(),
    'train_losses': train_losses,
    'val_losses': validation_losses,
    'epoch': current_epoch
}
torch.save(checkpoint, 'pre-trained_EffiecientNetB0_d02.pt') ## This is the final one

# %% [markdown]
# ### Load Model

# %%
# Reinitialize your model architecture
targets_size = len(dataset.class_to_idx) #38
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = EfficientNetB0_Model(targets_size).to(device)

# Load the full checkpoint (includes training history)
full_checkpoint = torch.load("pre-trained_EffiecientNetB0_d02.pt", map_location=device)
model.load_state_dict(full_checkpoint['model_state_dict'])

# Optionally, retrieve training history
train_losses = full_checkpoint.get('train_losses', None)
validation_losses   = full_checkpoint.get('val_losses', None)
epoch = full_checkpoint.get('epoch', None)

# Set model to evaluation mode
model.eval()

# (Optional) Verify the device of each parameter
for name, param in model.named_parameters():
    print(f"{name} is on {param.device}")
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_11048\105098034.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   full_checkpoint = torch.load("pre-trained_EffiecientNetB0_d02.pt", map_location=device)
# model.features.0.0.weight is on cuda:0
# model.features.0.1.weight is on cuda:0
# model.features.0.1.bias is on cuda:0
# model.features.1.0.block.0.0.weight is on cuda:0
# model.features.1.0.block.0.1.weight is on cuda:0
# model.features.1.0.block.0.1.bias is on cuda:0
# model.features.1.0.block.1.fc1.weight is on cuda:0
# model.features.1.0.block.1.fc1.bias is on cuda:0
# model.features.1.0.block.1.fc2.weight is on cuda:0
# model.features.1.0.block.1.fc2.bias is on cuda:0
# model.features.1.0.block.2.0.weight is on cuda:0
# model.features.1.0.block.2.1.weight is on cuda:0
# model.features.1.0.block.2.1.bias is on cuda:0
# model.features.2.0.block.0.0.weight is on cuda:0
# model.features.2.0.block.0.1.weight is on cuda:0
# model.features.2.0.block.0.1.bias is on cuda:0
# model.features.2.0.block.1.0.weight is on cuda:0
# model.features.2.0.block.1.1.weight is on cuda:0
# model.features.2.0.block.1.1.bias is on cuda:0
# model.features.2.0.block.2.fc1.weight is on cuda:0
# model.features.2.0.block.2.fc1.bias is on cuda:0
# model.features.2.0.block.2.fc2.weight is on cuda:0
# model.features.2.0.block.2.fc2.bias is on cuda:0
# model.features.2.0.block.3.0.weight is on cuda:0
# model.features.2.0.block.3.1.weight is on cuda:0
# model.features.2.0.block.3.1.bias is on cuda:0
# model.features.2.1.block.0.0.weight is on cuda:0
# model.features.2.1.block.0.1.weight is on cuda:0
# model.features.2.1.block.0.1.bias is on cuda:0
# model.features.2.1.block.1.0.weight is on cuda:0
# model.features.2.1.block.1.1.weight is on cuda:0
# model.features.2.1.block.1.1.bias is on cuda:0
# model.features.2.1.block.2.fc1.weight is on cuda:0
# model.features.2.1.block.2.fc1.bias is on cuda:0
# model.features.2.1.block.2.fc2.weight is on cuda:0
# model.features.2.1.block.2.fc2.bias is on cuda:0
# model.features.2.1.block.3.0.weight is on cuda:0
# model.features.2.1.block.3.1.weight is on cuda:0
# model.features.2.1.block.3.1.bias is on cuda:0
# model.features.3.0.block.0.0.weight is on cuda:0
# model.features.3.0.block.0.1.weight is on cuda:0
# model.features.3.0.block.0.1.bias is on cuda:0
# model.features.3.0.block.1.0.weight is on cuda:0
# model.features.3.0.block.1.1.weight is on cuda:0
# model.features.3.0.block.1.1.bias is on cuda:0
# model.features.3.0.block.2.fc1.weight is on cuda:0
# model.features.3.0.block.2.fc1.bias is on cuda:0
# model.features.3.0.block.2.fc2.weight is on cuda:0
# model.features.3.0.block.2.fc2.bias is on cuda:0
# model.features.3.0.block.3.0.weight is on cuda:0
# model.features.3.0.block.3.1.weight is on cuda:0
# model.features.3.0.block.3.1.bias is on cuda:0
# model.features.3.1.block.0.0.weight is on cuda:0
# model.features.3.1.block.0.1.weight is on cuda:0
# model.features.3.1.block.0.1.bias is on cuda:0
# model.features.3.1.block.1.0.weight is on cuda:0
# model.features.3.1.block.1.1.weight is on cuda:0
# model.features.3.1.block.1.1.bias is on cuda:0
# model.features.3.1.block.2.fc1.weight is on cuda:0
# model.features.3.1.block.2.fc1.bias is on cuda:0
# model.features.3.1.block.2.fc2.weight is on cuda:0
# model.features.3.1.block.2.fc2.bias is on cuda:0
# model.features.3.1.block.3.0.weight is on cuda:0
# model.features.3.1.block.3.1.weight is on cuda:0
# model.features.3.1.block.3.1.bias is on cuda:0
# model.features.4.0.block.0.0.weight is on cuda:0
# model.features.4.0.block.0.1.weight is on cuda:0
# model.features.4.0.block.0.1.bias is on cuda:0
# model.features.4.0.block.1.0.weight is on cuda:0
# model.features.4.0.block.1.1.weight is on cuda:0
# model.features.4.0.block.1.1.bias is on cuda:0
# model.features.4.0.block.2.fc1.weight is on cuda:0
# model.features.4.0.block.2.fc1.bias is on cuda:0
# model.features.4.0.block.2.fc2.weight is on cuda:0
# model.features.4.0.block.2.fc2.bias is on cuda:0
# model.features.4.0.block.3.0.weight is on cuda:0
# model.features.4.0.block.3.1.weight is on cuda:0
# model.features.4.0.block.3.1.bias is on cuda:0
# model.features.4.1.block.0.0.weight is on cuda:0
# model.features.4.1.block.0.1.weight is on cuda:0
# model.features.4.1.block.0.1.bias is on cuda:0
# model.features.4.1.block.1.0.weight is on cuda:0
# model.features.4.1.block.1.1.weight is on cuda:0
# model.features.4.1.block.1.1.bias is on cuda:0
# model.features.4.1.block.2.fc1.weight is on cuda:0
# model.features.4.1.block.2.fc1.bias is on cuda:0
# model.features.4.1.block.2.fc2.weight is on cuda:0
# model.features.4.1.block.2.fc2.bias is on cuda:0
# model.features.4.1.block.3.0.weight is on cuda:0
# model.features.4.1.block.3.1.weight is on cuda:0
# model.features.4.1.block.3.1.bias is on cuda:0
# model.features.4.2.block.0.0.weight is on cuda:0
# model.features.4.2.block.0.1.weight is on cuda:0
# model.features.4.2.block.0.1.bias is on cuda:0
# model.features.4.2.block.1.0.weight is on cuda:0
# model.features.4.2.block.1.1.weight is on cuda:0
# model.features.4.2.block.1.1.bias is on cuda:0
# model.features.4.2.block.2.fc1.weight is on cuda:0
# model.features.4.2.block.2.fc1.bias is on cuda:0
# model.features.4.2.block.2.fc2.weight is on cuda:0
# model.features.4.2.block.2.fc2.bias is on cuda:0
# model.features.4.2.block.3.0.weight is on cuda:0
# model.features.4.2.block.3.1.weight is on cuda:0
# model.features.4.2.block.3.1.bias is on cuda:0
# model.features.5.0.block.0.0.weight is on cuda:0
# model.features.5.0.block.0.1.weight is on cuda:0
# model.features.5.0.block.0.1.bias is on cuda:0
# model.features.5.0.block.1.0.weight is on cuda:0
# model.features.5.0.block.1.1.weight is on cuda:0
# model.features.5.0.block.1.1.bias is on cuda:0
# model.features.5.0.block.2.fc1.weight is on cuda:0
# model.features.5.0.block.2.fc1.bias is on cuda:0
# model.features.5.0.block.2.fc2.weight is on cuda:0
# model.features.5.0.block.2.fc2.bias is on cuda:0
# model.features.5.0.block.3.0.weight is on cuda:0
# model.features.5.0.block.3.1.weight is on cuda:0
# model.features.5.0.block.3.1.bias is on cuda:0
# model.features.5.1.block.0.0.weight is on cuda:0
# model.features.5.1.block.0.1.weight is on cuda:0
# model.features.5.1.block.0.1.bias is on cuda:0
# model.features.5.1.block.1.0.weight is on cuda:0
# model.features.5.1.block.1.1.weight is on cuda:0
# model.features.5.1.block.1.1.bias is on cuda:0
# model.features.5.1.block.2.fc1.weight is on cuda:0
# model.features.5.1.block.2.fc1.bias is on cuda:0
# model.features.5.1.block.2.fc2.weight is on cuda:0
# model.features.5.1.block.2.fc2.bias is on cuda:0
# model.features.5.1.block.3.0.weight is on cuda:0
# model.features.5.1.block.3.1.weight is on cuda:0
# model.features.5.1.block.3.1.bias is on cuda:0
# model.features.5.2.block.0.0.weight is on cuda:0
# model.features.5.2.block.0.1.weight is on cuda:0
# model.features.5.2.block.0.1.bias is on cuda:0
# model.features.5.2.block.1.0.weight is on cuda:0
# model.features.5.2.block.1.1.weight is on cuda:0
# model.features.5.2.block.1.1.bias is on cuda:0
# model.features.5.2.block.2.fc1.weight is on cuda:0
# model.features.5.2.block.2.fc1.bias is on cuda:0
# model.features.5.2.block.2.fc2.weight is on cuda:0
# model.features.5.2.block.2.fc2.bias is on cuda:0
# model.features.5.2.block.3.0.weight is on cuda:0
# model.features.5.2.block.3.1.weight is on cuda:0
# model.features.5.2.block.3.1.bias is on cuda:0
# model.features.6.0.block.0.0.weight is on cuda:0
# model.features.6.0.block.0.1.weight is on cuda:0
# model.features.6.0.block.0.1.bias is on cuda:0
# model.features.6.0.block.1.0.weight is on cuda:0
# model.features.6.0.block.1.1.weight is on cuda:0
# model.features.6.0.block.1.1.bias is on cuda:0
# model.features.6.0.block.2.fc1.weight is on cuda:0
# model.features.6.0.block.2.fc1.bias is on cuda:0
# model.features.6.0.block.2.fc2.weight is on cuda:0
# model.features.6.0.block.2.fc2.bias is on cuda:0
# model.features.6.0.block.3.0.weight is on cuda:0
# model.features.6.0.block.3.1.weight is on cuda:0
# model.features.6.0.block.3.1.bias is on cuda:0
# model.features.6.1.block.0.0.weight is on cuda:0
# model.features.6.1.block.0.1.weight is on cuda:0
# model.features.6.1.block.0.1.bias is on cuda:0
# model.features.6.1.block.1.0.weight is on cuda:0
# model.features.6.1.block.1.1.weight is on cuda:0
# model.features.6.1.block.1.1.bias is on cuda:0
# model.features.6.1.block.2.fc1.weight is on cuda:0
# model.features.6.1.block.2.fc1.bias is on cuda:0
# model.features.6.1.block.2.fc2.weight is on cuda:0
# model.features.6.1.block.2.fc2.bias is on cuda:0
# model.features.6.1.block.3.0.weight is on cuda:0
# model.features.6.1.block.3.1.weight is on cuda:0
# model.features.6.1.block.3.1.bias is on cuda:0
# model.features.6.2.block.0.0.weight is on cuda:0
# model.features.6.2.block.0.1.weight is on cuda:0
# model.features.6.2.block.0.1.bias is on cuda:0
# model.features.6.2.block.1.0.weight is on cuda:0
# model.features.6.2.block.1.1.weight is on cuda:0
# model.features.6.2.block.1.1.bias is on cuda:0
# model.features.6.2.block.2.fc1.weight is on cuda:0
# model.features.6.2.block.2.fc1.bias is on cuda:0
# model.features.6.2.block.2.fc2.weight is on cuda:0
# model.features.6.2.block.2.fc2.bias is on cuda:0
# model.features.6.2.block.3.0.weight is on cuda:0
# model.features.6.2.block.3.1.weight is on cuda:0
# model.features.6.2.block.3.1.bias is on cuda:0
# model.features.6.3.block.0.0.weight is on cuda:0
# model.features.6.3.block.0.1.weight is on cuda:0
# model.features.6.3.block.0.1.bias is on cuda:0
# model.features.6.3.block.1.0.weight is on cuda:0
# model.features.6.3.block.1.1.weight is on cuda:0
# model.features.6.3.block.1.1.bias is on cuda:0
# model.features.6.3.block.2.fc1.weight is on cuda:0
# model.features.6.3.block.2.fc1.bias is on cuda:0
# model.features.6.3.block.2.fc2.weight is on cuda:0
# model.features.6.3.block.2.fc2.bias is on cuda:0
# model.features.6.3.block.3.0.weight is on cuda:0
# model.features.6.3.block.3.1.weight is on cuda:0
# model.features.6.3.block.3.1.bias is on cuda:0
# model.features.7.0.block.0.0.weight is on cuda:0
# model.features.7.0.block.0.1.weight is on cuda:0
# model.features.7.0.block.0.1.bias is on cuda:0
# model.features.7.0.block.1.0.weight is on cuda:0
# model.features.7.0.block.1.1.weight is on cuda:0
# model.features.7.0.block.1.1.bias is on cuda:0
# model.features.7.0.block.2.fc1.weight is on cuda:0
# model.features.7.0.block.2.fc1.bias is on cuda:0
# model.features.7.0.block.2.fc2.weight is on cuda:0
# model.features.7.0.block.2.fc2.bias is on cuda:0
# model.features.7.0.block.3.0.weight is on cuda:0
# model.features.7.0.block.3.1.weight is on cuda:0
# model.features.7.0.block.3.1.bias is on cuda:0
# model.features.8.0.weight is on cuda:0
# model.features.8.1.weight is on cuda:0
# model.features.8.1.bias is on cuda:0
# model.classifier.1.weight is on cuda:0
# model.classifier.1.bias is on cuda:0

# %% [markdown]
# ### Plot the loss

# %%
import matplotlib.pyplot as plt

def plot_learning_curve(train_losses, validation_losses):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_losses, 'bo-', label='Training Loss')
    plt.plot(epochs, validation_losses, 'ro-', label='Validation Loss')
    
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# After your training loop finishes and you have train_losses and validation_losses:
plot_learning_curve(train_losses, validation_losses)

# %%
plt.plot(train_losses , label = 'train_loss')
plt.plot(validation_losses , label = 'validation_loss')
plt.xticks(range(1, len(train_losses) + 1))
plt.xlabel('No of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Accuracy

# %%
from tabulate import tabulate  # pip install tabulate

def accuracy(loader, model, device):
    # Set model to evaluation mode
    model.eval()
    
    # Initialize counters
    n_correct = 0
    n_total = 0
    num_classes = len(loader.dataset.classes)
    correct_per_class = np.zeros(num_classes)
    total_per_class = np.zeros(num_classes)
    
    # Disable gradient computation
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            # Update overall counters
            n_correct += (predictions == targets).sum().item()
            n_total += targets.size(0)
            
            # Update per-class counters
            for i in range(num_classes):
                correct_per_class[i] += ((predictions == i) & (targets == i)).sum().item()
                total_per_class[i] += (targets == i).sum().item()
    
    # Calculate overall accuracy
    overall_accuracy = n_correct / n_total
    
    # Calculate per-class accuracy
    per_class_accuracy = correct_per_class / total_per_class
    per_class_accuracy = np.nan_to_num(per_class_accuracy)  # Handle division by zero
    
    # Create table data using tabulate
    table_data = []
    for i, class_name in enumerate(loader.dataset.classes):
        table_data.append([class_name, f"{per_class_accuracy[i] * 100:.2f}"])
    
    print("\nPer-Class Accuracy:")
    print(tabulate(table_data, headers=["Category", "Accuracy (%)"], tablefmt="github"))
    
    return overall_accuracy, per_class_accuracy

# %%
train_overall_acc, per_class_acc = accuracy(train_loader, model, device)
print(f"Overall Training Accuracy: {train_overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                      |   Accuracy (%) |
# |-----------------------------------------------|----------------|
# | Apple___Apple_scab                            |          99.94 |
# | Apple___Black_rot                             |         100    |
# | Apple___Cedar_apple_rust                      |         100    |
# | Apple___healthy                               |         100    |
# | Background_without_leaves                     |          99.94 |
# | Blueberry___healthy                           |          99.94 |
# | Cherry___Powdery_mildew                       |         100    |
# | Cherry___healthy                              |         100    |
# | Corn___Cercospora_leaf_spot Gray_leaf_spot    |         100    |
# | Corn___Common_rust                            |         100    |
# | Corn___Northern_Leaf_Blight                   |          99.94 |
# | Corn___healthy                                |         100    |
# | Grape___Black_rot                             |         100    |
# | Grape___Esca_(Black_Measles)                  |         100    |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)    |         100    |
# | Grape___healthy                               |         100    |
# | Orange___Haunglongbing_(Citrus_greening)      |         100    |
# | Peach___Bacterial_spot                        |         100    |
# | Peach___healthy                               |         100    |
# | Pepper,_bell___Bacterial_spot                 |         100    |
# | Pepper,_bell___healthy                        |         100    |
# | Potato___Early_blight                         |         100    |
# | Potato___Late_blight                          |         100    |
# | Potato___healthy                              |         100    |
# | Raspberry___healthy                           |         100    |
# | Soybean___healthy                             |         100    |
# | Squash___Powdery_mildew                       |         100    |
# | Strawberry___Leaf_scorch                      |         100    |
# | Strawberry___healthy                          |         100    |
# | Tomato___Bacterial_spot                       |         100    |
# | Tomato___Early_blight                         |         100    |
# | Tomato___Late_blight                          |          99.94 |
# | Tomato___Leaf_Mold                            |         100    |
# | Tomato___Septoria_leaf_spot                   |         100    |
# | Tomato___Spider_mites Two-spotted_spider_mite |         100    |
# | Tomato___Target_Spot                          |         100    |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus        |         100    |
# | Tomato___Tomato_mosaic_virus                  |         100    |
# | Tomato___healthy                              |         100    |
# Overall Training Accuracy: 0.9999

# %%
val_overall_acc, per_class_acc = accuracy(validation_loader, model, device)
print(f"Overall Validation Accuracy: {val_overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                      |   Accuracy (%) |
# |-----------------------------------------------|----------------|
# | Apple___Apple_scab                            |          100   |
# | Apple___Black_rot                             |          100   |
# | Apple___Cedar_apple_rust                      |          100   |
# | Apple___healthy                               |          100   |
# | Background_without_leaves                     |          100   |
# | Blueberry___healthy                           |          100   |
# | Cherry___Powdery_mildew                       |          100   |
# | Cherry___healthy                              |          100   |
# | Corn___Cercospora_leaf_spot Gray_leaf_spot    |           98.5 |
# | Corn___Common_rust                            |          100   |
# | Corn___Northern_Leaf_Blight                   |           98   |
# | Corn___healthy                                |          100   |
# | Grape___Black_rot                             |          100   |
# | Grape___Esca_(Black_Measles)                  |          100   |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)    |          100   |
# | Grape___healthy                               |          100   |
# | Orange___Haunglongbing_(Citrus_greening)      |          100   |
# | Peach___Bacterial_spot                        |          100   |
# | Peach___healthy                               |          100   |
# | Pepper,_bell___Bacterial_spot                 |          100   |
# | Pepper,_bell___healthy                        |          100   |
# | Potato___Early_blight                         |          100   |
# | Potato___Late_blight                          |          100   |
# | Potato___healthy                              |          100   |
# | Raspberry___healthy                           |          100   |
# | Soybean___healthy                             |          100   |
# | Squash___Powdery_mildew                       |          100   |
# | Strawberry___Leaf_scorch                      |          100   |
# | Strawberry___healthy                          |          100   |
# | Tomato___Bacterial_spot                       |           99.5 |
# | Tomato___Early_blight                         |           99.5 |
# | Tomato___Late_blight                          |           99.5 |
# | Tomato___Leaf_Mold                            |          100   |
# | Tomato___Septoria_leaf_spot                   |           99.5 |
# | Tomato___Spider_mites Two-spotted_spider_mite |           99.5 |
# | Tomato___Target_Spot                          |           99.5 |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus        |          100   |
# | Tomato___Tomato_mosaic_virus                  |          100   |
# | Tomato___healthy                              |          100   |
# Overall Validation Accuracy: 0.9983

# %%
overall_acc, per_class_acc = accuracy(test_loader, model, device)
print(f"Overall Testing Accuracy: {overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                      |   Accuracy (%) |
# |-----------------------------------------------|----------------|
# | Apple___Apple_scab                            |           99.5 |
# | Apple___Black_rot                             |          100   |
# | Apple___Cedar_apple_rust                      |          100   |
# | Apple___healthy                               |          100   |
# | Background_without_leaves                     |          100   |
# | Blueberry___healthy                           |          100   |
# | Cherry___Powdery_mildew                       |          100   |
# | Cherry___healthy                              |          100   |
# | Corn___Cercospora_leaf_spot Gray_leaf_spot    |           98   |
# | Corn___Common_rust                            |          100   |
# | Corn___Northern_Leaf_Blight                   |           97   |
# | Corn___healthy                                |          100   |
# | Grape___Black_rot                             |          100   |
# | Grape___Esca_(Black_Measles)                  |          100   |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)    |          100   |
# | Grape___healthy                               |          100   |
# | Orange___Haunglongbing_(Citrus_greening)      |          100   |
# | Peach___Bacterial_spot                        |          100   |
# | Peach___healthy                               |          100   |
# | Pepper,_bell___Bacterial_spot                 |          100   |
# | Pepper,_bell___healthy                        |          100   |
# | Potato___Early_blight                         |          100   |
# | Potato___Late_blight                          |           99.5 |
# | Potato___healthy                              |          100   |
# | Raspberry___healthy                           |          100   |
# | Soybean___healthy                             |           99.5 |
# | Squash___Powdery_mildew                       |          100   |
# | Strawberry___Leaf_scorch                      |          100   |
# | Strawberry___healthy                          |          100   |
# | Tomato___Bacterial_spot                       |          100   |
# | Tomato___Early_blight                         |           99   |
# | Tomato___Late_blight                          |          100   |
# | Tomato___Leaf_Mold                            |          100   |
# | Tomato___Septoria_leaf_spot                   |          100   |
# | Tomato___Spider_mites Two-spotted_spider_mite |          100   |
# | Tomato___Target_Spot                          |          100   |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus        |           99.5 |
# | Tomato___Tomato_mosaic_virus                  |          100   |
# | Tomato___healthy                              |          100   |
# Overall Testing Accuracy: 0.9979

# %%
print(
    f"Train Accuracy : {train_overall_acc} \nTest Accuracy : {overall_acc}\nValidation Accuracy : {val_overall_acc}"
)
# Out:
# Train Accuracy : 0.9999198717948717
# Test Accuracy : 0.997948717948718
# Validation Accuracy : 0.9983333333333333

# %% [markdown]
# ### Precision, Recall and F1-score

# %%
import pandas as pd
from sklearn.metrics import classification_report

def evaluate_metrics(loader):
    y_true = []
    y_pred = []

    # Ensure model is in eval mode and disable gradients
    model.eval()
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())
    
    # Get the report as a dictionary
    report_dict = classification_report(y_true, y_pred, target_names=dataset.classes, output_dict=True)
    
    # Convert dictionary to a Pandas DataFrame and transpose it so that each row is a class.
    report_df = pd.DataFrame(report_dict).transpose()
    return report_df

# Calculate metrics for each set
train_report = evaluate_metrics(train_loader)
validation_report = evaluate_metrics(validation_loader)
test_report = evaluate_metrics(test_loader)

# %%
# Write the reports to an Excel file with multiple sheets
excel_filename = "metrics_pre-trained_EfficientNetB0_d02.xlsx"
with pd.ExcelWriter(excel_filename) as writer:
    train_report.to_excel(writer, sheet_name="train")
    validation_report.to_excel(writer, sheet_name="validation")
    test_report.to_excel(writer, sheet_name="test")

print(f"Metrics saved to {excel_filename}")
# Out:
# Metrics saved to metrics_pre-trained_EfficientNetB0_d02.xlsx

# %% [markdown]
# ### Confusion Matrix

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_confusion_matrix(loader):
    y_true = []
    y_pred = []
    
    # Ensure the model is in evaluation mode
    model.eval()
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Convert to a DataFrame for better labeling
    cm_df = pd.DataFrame(cm, index=dataset.classes, columns=dataset.classes)
    return cm_df

def plot_confusion_matrix(cm_df, title="Confusion Matrix"):
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=True, annot_kws={"size": 8})
    plt.title(title, fontsize=18)
    plt.ylabel("Actual", fontsize=14)
    plt.xlabel("Predicted", fontsize=14)
    plt.show()

# %%
# Evaluate confusion matrices for train, validation, and test sets
cm_train = evaluate_confusion_matrix(train_loader)
cm_val = evaluate_confusion_matrix(validation_loader)
cm_test = evaluate_confusion_matrix(test_loader)

# %%
# Plot the confusion matrices
plot_confusion_matrix(cm_train, title="Train Confusion Matrix")
plot_confusion_matrix(cm_val, title="Validation Confusion Matrix")
plot_confusion_matrix(cm_test, title="Test Confusion Matrix")
