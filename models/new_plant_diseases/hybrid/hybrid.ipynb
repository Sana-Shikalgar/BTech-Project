# %% [markdown]
# ### IMPORTING IMPORTANT LIBRARIES

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !c:\users\ajay\documents\sana\env\scripts\python.exe -m pip install --upgrade pip
# !pip install torch
# !pip install torchvision
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install scikit-learn
# !pip install seaborn
# !pip install tabulate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
# torch.__version__
from torchvision import datasets, transforms, models  # datsets  , transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
from datetime import datetime

# %%
torch.cuda.empty_cache()
torch.no_grad()
torch.cuda.synchronize()
# !python3 --version
# Out:
# Python 3.8.10

# %% [markdown]
# ### Import Dataset

# %% [markdown]
# <b> Dataset Link (New Plant Disease ):</b><br> <a href="https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset"> https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset </a>

# %%
transform = transforms.Compose(
    [transforms.Resize(255), transforms.CenterCrop(224), transforms.ToTensor()]
)

# %%
# The the link to where you have stored the dataset.
dataset = datasets.ImageFolder("../../All_Datasets/New Plant Diseases Dataset(Balanced)", transform=transform)

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 87400
#     Root location: ../../All_Datasets/New Plant Diseases Dataset(Balanced)
#     StandardTransform
# Transform: Compose(
#                Resize(size=255, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#            )

# %% [markdown]
# ### Validation

# %%
# Suppose your dataset has integer class labels in dataset.targets
y = np.array(dataset.targets)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# --- Step 1: Create train+val vs. test (90% / 10%)
sss1 = StratifiedShuffleSplit(n_splits=1, test_size=0.10, random_state=42)
train_val_indices, test_indices = next(sss1.split(np.zeros(len(y)), y))

# %%
# --- Step 2: From train+val, split into train vs. validation
#  (We want validation to be 10% of the whole dataset, which is 1/9 of train+val)
sss2 = StratifiedShuffleSplit(n_splits=1, test_size=0.1111, random_state=42)
y_train_val = y[train_val_indices]
train_indices_sub, val_indices_sub = next(sss2.split(np.zeros(len(y_train_val)), y_train_val))

# %%
# Convert the local indices back to the original dataset’s indexing
train_indices = train_val_indices[train_indices_sub]
val_indices   = train_val_indices[val_indices_sub]

# %% [markdown]
# ### Split into Train and Test

# %%
# Create samplers
train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)
test_sampler = SubsetRandomSampler(test_indices)

# %%
print("Train size:", len(train_indices))
print("Validation size:", len(val_indices))
print("Test size:", len(test_indices))
# Out:
# Train size: 69920
# Validation size: 8740
# Test size: 8740

# %%
targets_size = len(dataset.class_to_idx)
print(targets_size)
# Out:
# 38

# %% [markdown]
# ### Original Modeling - Only removed the final classification layer

# %%
class CNNFeatureExtractor(nn.Module):
    def __init__(self):
        super(CNNFeatureExtractor, self).__init__()
        
        # Same conv layers as your CNN
        self.conv_layers = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2),
        )

        # Replace your original dense_layers with a feature-extraction layer
        self.feature_layers = nn.Sequential(
            nn.Dropout(0.4),
            nn.Linear(50176, 1024),
            nn.ReLU(),
            nn.Dropout(0.4)
            # Removed the final classification layer so we output a feature vector
        )

    def forward(self, X):
        out = self.conv_layers(X)
        # Flatten
        out = out.view(-1, 50176)
        out = self.feature_layers(out)   # shape: [B, 1024]
        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
model_original = CNNFeatureExtractor().to(device)

# %%
model_original.to(device)
# Out:
# CNNFeatureExtractor(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU()
#     (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (feature_layers): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=50176, out_features=1024, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#   )
# )

# %%
# !pip install torchsummary
from torchsummary import summary

summary(model_original, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#               ReLU-2         [-1, 32, 224, 224]               0
#        BatchNorm2d-3         [-1, 32, 224, 224]              64
#             Conv2d-4         [-1, 32, 224, 224]           9,248
#               ReLU-5         [-1, 32, 224, 224]               0
#        BatchNorm2d-6         [-1, 32, 224, 224]              64
#          MaxPool2d-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]          18,496
#               ReLU-9         [-1, 64, 112, 112]               0
#       BatchNorm2d-10         [-1, 64, 112, 112]             128
#            Conv2d-11         [-1, 64, 112, 112]          36,928
#              ReLU-12         [-1, 64, 112, 112]               0
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
#         MaxPool2d-14           [-1, 64, 56, 56]               0
#            Conv2d-15          [-1, 128, 56, 56]          73,856
#              ReLU-16          [-1, 128, 56, 56]               0
#       BatchNorm2d-17          [-1, 128, 56, 56]             256
#            Conv2d-18          [-1, 128, 56, 56]         147,584
#              ReLU-19          [-1, 128, 56, 56]               0
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#         MaxPool2d-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 256, 28, 28]         295,168
#              ReLU-23          [-1, 256, 28, 28]               0
#       BatchNorm2d-24          [-1, 256, 28, 28]             512
#            Conv2d-25          [-1, 256, 28, 28]         590,080
#              ReLU-26          [-1, 256, 28, 28]               0
#       BatchNorm2d-27          [-1, 256, 28, 28]             512
#         MaxPool2d-28          [-1, 256, 14, 14]               0
#           Dropout-29                [-1, 50176]               0
#            Linear-30                 [-1, 1024]      51,381,248
#              ReLU-31                 [-1, 1024]               0
#           Dropout-32                 [-1, 1024]               0
# ================================================================
# Total params: 52,555,424
# Trainable params: 52,555,424
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 143.96
# Params size (MB): 200.48
# Estimated Total Size (MB): 345.02
# ----------------------------------------------------------------

# %% [markdown]
# ### Hybrid Model with EfficientNet-B0

# %%
class HybridModelEfficientNet(nn.Module):
    def __init__(self, K):
        super(HybridModelEfficientNet, self).__init__()
        
        # Custom CNN for features
        self.custom_branch = CNNFeatureExtractor()
        
        # Pretrained EfficientNet-B0
        # Pretrained EfficientNet-B0 with updated weights parameter
        from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
        self.pretrained_branch = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
    
        # Remove the final classifier layer
        # Typically efficientnet_b0 has classifier = Sequential(...),
        # so we set it to Identity:
        self.pretrained_branch.classifier[1] = nn.Identity()  
        # Now it outputs a 1280-dim feature vector
        
        # Fusion layer: combine 1024 (custom) + 1280 (EfficientNet) = 2304
        self.fusion = nn.Sequential(
            nn.Linear(1024 + 1280, 1024),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(1024, K)
        )

    def forward(self, X):
        feat_custom = self.custom_branch(X)                # [B, 1024]
        feat_pretrained = self.pretrained_branch(X)        # [B, 1280]
        combined_feats = torch.cat([feat_custom, feat_pretrained], dim=1)  # [B, 2304]
        out = self.fusion(combined_feats)                  # [B, K]
        return out

# %%
model = HybridModelEfficientNet(targets_size).to(device)

# %%
model.to(device)
# Out:
# HybridModelEfficientNet(
#   (custom_branch): CNNFeatureExtractor(
#     (conv_layers): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU()
#       (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU()
#       (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU()
#       (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU()
#       (16): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU()
#       (19): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (21): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU()
#       (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (25): ReLU()
#       (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (feature_layers): Sequential(
#       (0): Dropout(p=0.4, inplace=False)
#       (1): Linear(in_features=50176, out_features=1024, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4, inplace=False)
#     )
#   )
#   (pretrained_branch): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#         )
#       )
#       (3): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#         )
#       )
#       (5): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#         )
#       )
#       (7): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#         )
#       )
#       (8): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=True)
#       (1): Identity()
#     )
#   )
#   (fusion): Sequential(
#     (0): Linear(in_features=2304, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=1024, out_features=38, bias=True)
#   )
# )

# %%
from torchsummary import summary
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#               ReLU-2         [-1, 32, 224, 224]               0
#        BatchNorm2d-3         [-1, 32, 224, 224]              64
#             Conv2d-4         [-1, 32, 224, 224]           9,248
#               ReLU-5         [-1, 32, 224, 224]               0
#        BatchNorm2d-6         [-1, 32, 224, 224]              64
#          MaxPool2d-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]          18,496
#               ReLU-9         [-1, 64, 112, 112]               0
#       BatchNorm2d-10         [-1, 64, 112, 112]             128
#            Conv2d-11         [-1, 64, 112, 112]          36,928
#              ReLU-12         [-1, 64, 112, 112]               0
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
#         MaxPool2d-14           [-1, 64, 56, 56]               0
#            Conv2d-15          [-1, 128, 56, 56]          73,856
#              ReLU-16          [-1, 128, 56, 56]               0
#       BatchNorm2d-17          [-1, 128, 56, 56]             256
#            Conv2d-18          [-1, 128, 56, 56]         147,584
#              ReLU-19          [-1, 128, 56, 56]               0
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#         MaxPool2d-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 256, 28, 28]         295,168
#              ReLU-23          [-1, 256, 28, 28]               0
#       BatchNorm2d-24          [-1, 256, 28, 28]             512
#            Conv2d-25          [-1, 256, 28, 28]         590,080
#              ReLU-26          [-1, 256, 28, 28]               0
#       BatchNorm2d-27          [-1, 256, 28, 28]             512
#         MaxPool2d-28          [-1, 256, 14, 14]               0
#           Dropout-29                [-1, 50176]               0
#            Linear-30                 [-1, 1024]      51,381,248
#              ReLU-31                 [-1, 1024]               0
#           Dropout-32                 [-1, 1024]               0
# CNNFeatureExtractor-33                 [-1, 1024]               0
#            Conv2d-34         [-1, 32, 112, 112]             864
#       BatchNorm2d-35         [-1, 32, 112, 112]              64
#              SiLU-36         [-1, 32, 112, 112]               0
#            Conv2d-37         [-1, 32, 112, 112]             288
#       BatchNorm2d-38         [-1, 32, 112, 112]              64
#              SiLU-39         [-1, 32, 112, 112]               0
# AdaptiveAvgPool2d-40             [-1, 32, 1, 1]               0
#            Conv2d-41              [-1, 8, 1, 1]             264
#              SiLU-42              [-1, 8, 1, 1]               0
#            Conv2d-43             [-1, 32, 1, 1]             288
#           Sigmoid-44             [-1, 32, 1, 1]               0
# SqueezeExcitation-45         [-1, 32, 112, 112]               0
#            Conv2d-46         [-1, 16, 112, 112]             512
#       BatchNorm2d-47         [-1, 16, 112, 112]              32
#            MBConv-48         [-1, 16, 112, 112]               0
#            Conv2d-49         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-50         [-1, 96, 112, 112]             192
#              SiLU-51         [-1, 96, 112, 112]               0
#            Conv2d-52           [-1, 96, 56, 56]             864
#       BatchNorm2d-53           [-1, 96, 56, 56]             192
#              SiLU-54           [-1, 96, 56, 56]               0
# AdaptiveAvgPool2d-55             [-1, 96, 1, 1]               0
#            Conv2d-56              [-1, 4, 1, 1]             388
#              SiLU-57              [-1, 4, 1, 1]               0
#            Conv2d-58             [-1, 96, 1, 1]             480
#           Sigmoid-59             [-1, 96, 1, 1]               0
# SqueezeExcitation-60           [-1, 96, 56, 56]               0
#            Conv2d-61           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-62           [-1, 24, 56, 56]              48
#            MBConv-63           [-1, 24, 56, 56]               0
#            Conv2d-64          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-65          [-1, 144, 56, 56]             288
#              SiLU-66          [-1, 144, 56, 56]               0
#            Conv2d-67          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-68          [-1, 144, 56, 56]             288
#              SiLU-69          [-1, 144, 56, 56]               0
# AdaptiveAvgPool2d-70            [-1, 144, 1, 1]               0
#            Conv2d-71              [-1, 6, 1, 1]             870
#              SiLU-72              [-1, 6, 1, 1]               0
#            Conv2d-73            [-1, 144, 1, 1]           1,008
#           Sigmoid-74            [-1, 144, 1, 1]               0
# SqueezeExcitation-75          [-1, 144, 56, 56]               0
#            Conv2d-76           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-77           [-1, 24, 56, 56]              48
#   StochasticDepth-78           [-1, 24, 56, 56]               0
#            MBConv-79           [-1, 24, 56, 56]               0
#            Conv2d-80          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-81          [-1, 144, 56, 56]             288
#              SiLU-82          [-1, 144, 56, 56]               0
#            Conv2d-83          [-1, 144, 28, 28]           3,600
#       BatchNorm2d-84          [-1, 144, 28, 28]             288
#              SiLU-85          [-1, 144, 28, 28]               0
# AdaptiveAvgPool2d-86            [-1, 144, 1, 1]               0
#            Conv2d-87              [-1, 6, 1, 1]             870
#              SiLU-88              [-1, 6, 1, 1]               0
#            Conv2d-89            [-1, 144, 1, 1]           1,008
#           Sigmoid-90            [-1, 144, 1, 1]               0
# SqueezeExcitation-91          [-1, 144, 28, 28]               0
#            Conv2d-92           [-1, 40, 28, 28]           5,760
#       BatchNorm2d-93           [-1, 40, 28, 28]              80
#            MBConv-94           [-1, 40, 28, 28]               0
#            Conv2d-95          [-1, 240, 28, 28]           9,600
#       BatchNorm2d-96          [-1, 240, 28, 28]             480
#              SiLU-97          [-1, 240, 28, 28]               0
#            Conv2d-98          [-1, 240, 28, 28]           6,000
#       BatchNorm2d-99          [-1, 240, 28, 28]             480
#             SiLU-100          [-1, 240, 28, 28]               0
# AdaptiveAvgPool2d-101            [-1, 240, 1, 1]               0
#           Conv2d-102             [-1, 10, 1, 1]           2,410
#             SiLU-103             [-1, 10, 1, 1]               0
#           Conv2d-104            [-1, 240, 1, 1]           2,640
#          Sigmoid-105            [-1, 240, 1, 1]               0
# SqueezeExcitation-106          [-1, 240, 28, 28]               0
#           Conv2d-107           [-1, 40, 28, 28]           9,600
#      BatchNorm2d-108           [-1, 40, 28, 28]              80
#  StochasticDepth-109           [-1, 40, 28, 28]               0
#           MBConv-110           [-1, 40, 28, 28]               0
#           Conv2d-111          [-1, 240, 28, 28]           9,600
#      BatchNorm2d-112          [-1, 240, 28, 28]             480
#             SiLU-113          [-1, 240, 28, 28]               0
#           Conv2d-114          [-1, 240, 14, 14]           2,160
#      BatchNorm2d-115          [-1, 240, 14, 14]             480
#             SiLU-116          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-117            [-1, 240, 1, 1]               0
#           Conv2d-118             [-1, 10, 1, 1]           2,410
#             SiLU-119             [-1, 10, 1, 1]               0
#           Conv2d-120            [-1, 240, 1, 1]           2,640
#          Sigmoid-121            [-1, 240, 1, 1]               0
# SqueezeExcitation-122          [-1, 240, 14, 14]               0
#           Conv2d-123           [-1, 80, 14, 14]          19,200
#      BatchNorm2d-124           [-1, 80, 14, 14]             160
#           MBConv-125           [-1, 80, 14, 14]               0
#           Conv2d-126          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-127          [-1, 480, 14, 14]             960
#             SiLU-128          [-1, 480, 14, 14]               0
#           Conv2d-129          [-1, 480, 14, 14]           4,320
#      BatchNorm2d-130          [-1, 480, 14, 14]             960
#             SiLU-131          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-132            [-1, 480, 1, 1]               0
#           Conv2d-133             [-1, 20, 1, 1]           9,620
#             SiLU-134             [-1, 20, 1, 1]               0
#           Conv2d-135            [-1, 480, 1, 1]          10,080
#          Sigmoid-136            [-1, 480, 1, 1]               0
# SqueezeExcitation-137          [-1, 480, 14, 14]               0
#           Conv2d-138           [-1, 80, 14, 14]          38,400
#      BatchNorm2d-139           [-1, 80, 14, 14]             160
#  StochasticDepth-140           [-1, 80, 14, 14]               0
#           MBConv-141           [-1, 80, 14, 14]               0
#           Conv2d-142          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-143          [-1, 480, 14, 14]             960
#             SiLU-144          [-1, 480, 14, 14]               0
#           Conv2d-145          [-1, 480, 14, 14]           4,320
#      BatchNorm2d-146          [-1, 480, 14, 14]             960
#             SiLU-147          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-148            [-1, 480, 1, 1]               0
#           Conv2d-149             [-1, 20, 1, 1]           9,620
#             SiLU-150             [-1, 20, 1, 1]               0
#           Conv2d-151            [-1, 480, 1, 1]          10,080
#          Sigmoid-152            [-1, 480, 1, 1]               0
# SqueezeExcitation-153          [-1, 480, 14, 14]               0
#           Conv2d-154           [-1, 80, 14, 14]          38,400
#      BatchNorm2d-155           [-1, 80, 14, 14]             160
#  StochasticDepth-156           [-1, 80, 14, 14]               0
#           MBConv-157           [-1, 80, 14, 14]               0
#           Conv2d-158          [-1, 480, 14, 14]          38,400
#      BatchNorm2d-159          [-1, 480, 14, 14]             960
#             SiLU-160          [-1, 480, 14, 14]               0
#           Conv2d-161          [-1, 480, 14, 14]          12,000
#      BatchNorm2d-162          [-1, 480, 14, 14]             960
#             SiLU-163          [-1, 480, 14, 14]               0
# AdaptiveAvgPool2d-164            [-1, 480, 1, 1]               0
#           Conv2d-165             [-1, 20, 1, 1]           9,620
#             SiLU-166             [-1, 20, 1, 1]               0
#           Conv2d-167            [-1, 480, 1, 1]          10,080
#          Sigmoid-168            [-1, 480, 1, 1]               0
# SqueezeExcitation-169          [-1, 480, 14, 14]               0
#           Conv2d-170          [-1, 112, 14, 14]          53,760
#      BatchNorm2d-171          [-1, 112, 14, 14]             224
#           MBConv-172          [-1, 112, 14, 14]               0
#           Conv2d-173          [-1, 672, 14, 14]          75,264
#      BatchNorm2d-174          [-1, 672, 14, 14]           1,344
#             SiLU-175          [-1, 672, 14, 14]               0
#           Conv2d-176          [-1, 672, 14, 14]          16,800
#      BatchNorm2d-177          [-1, 672, 14, 14]           1,344
#             SiLU-178          [-1, 672, 14, 14]               0
# AdaptiveAvgPool2d-179            [-1, 672, 1, 1]               0
#           Conv2d-180             [-1, 28, 1, 1]          18,844
#             SiLU-181             [-1, 28, 1, 1]               0
#           Conv2d-182            [-1, 672, 1, 1]          19,488
#          Sigmoid-183            [-1, 672, 1, 1]               0
# SqueezeExcitation-184          [-1, 672, 14, 14]               0
#           Conv2d-185          [-1, 112, 14, 14]          75,264
#      BatchNorm2d-186          [-1, 112, 14, 14]             224
#  StochasticDepth-187          [-1, 112, 14, 14]               0
#           MBConv-188          [-1, 112, 14, 14]               0
#           Conv2d-189          [-1, 672, 14, 14]          75,264
#      BatchNorm2d-190          [-1, 672, 14, 14]           1,344
#             SiLU-191          [-1, 672, 14, 14]               0
#           Conv2d-192          [-1, 672, 14, 14]          16,800
#      BatchNorm2d-193          [-1, 672, 14, 14]           1,344
#             SiLU-194          [-1, 672, 14, 14]               0
# AdaptiveAvgPool2d-195            [-1, 672, 1, 1]               0
#           Conv2d-196             [-1, 28, 1, 1]          18,844
#             SiLU-197             [-1, 28, 1, 1]               0
#           Conv2d-198            [-1, 672, 1, 1]          19,488
#          Sigmoid-199            [-1, 672, 1, 1]               0
# SqueezeExcitation-200          [-1, 672, 14, 14]               0
#           Conv2d-201          [-1, 112, 14, 14]          75,264
#      BatchNorm2d-202          [-1, 112, 14, 14]             224
#  StochasticDepth-203          [-1, 112, 14, 14]               0
#           MBConv-204          [-1, 112, 14, 14]               0
#           Conv2d-205          [-1, 672, 14, 14]          75,264
#      BatchNorm2d-206          [-1, 672, 14, 14]           1,344
#             SiLU-207          [-1, 672, 14, 14]               0
#           Conv2d-208            [-1, 672, 7, 7]          16,800
#      BatchNorm2d-209            [-1, 672, 7, 7]           1,344
#             SiLU-210            [-1, 672, 7, 7]               0
# AdaptiveAvgPool2d-211            [-1, 672, 1, 1]               0
#           Conv2d-212             [-1, 28, 1, 1]          18,844
#             SiLU-213             [-1, 28, 1, 1]               0
#           Conv2d-214            [-1, 672, 1, 1]          19,488
#          Sigmoid-215            [-1, 672, 1, 1]               0
# SqueezeExcitation-216            [-1, 672, 7, 7]               0
#           Conv2d-217            [-1, 192, 7, 7]         129,024
#      BatchNorm2d-218            [-1, 192, 7, 7]             384
#           MBConv-219            [-1, 192, 7, 7]               0
#           Conv2d-220           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-221           [-1, 1152, 7, 7]           2,304
#             SiLU-222           [-1, 1152, 7, 7]               0
#           Conv2d-223           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-224           [-1, 1152, 7, 7]           2,304
#             SiLU-225           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-226           [-1, 1152, 1, 1]               0
#           Conv2d-227             [-1, 48, 1, 1]          55,344
#             SiLU-228             [-1, 48, 1, 1]               0
#           Conv2d-229           [-1, 1152, 1, 1]          56,448
#          Sigmoid-230           [-1, 1152, 1, 1]               0
# SqueezeExcitation-231           [-1, 1152, 7, 7]               0
#           Conv2d-232            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-233            [-1, 192, 7, 7]             384
#  StochasticDepth-234            [-1, 192, 7, 7]               0
#           MBConv-235            [-1, 192, 7, 7]               0
#           Conv2d-236           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-237           [-1, 1152, 7, 7]           2,304
#             SiLU-238           [-1, 1152, 7, 7]               0
#           Conv2d-239           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-240           [-1, 1152, 7, 7]           2,304
#             SiLU-241           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-242           [-1, 1152, 1, 1]               0
#           Conv2d-243             [-1, 48, 1, 1]          55,344
#             SiLU-244             [-1, 48, 1, 1]               0
#           Conv2d-245           [-1, 1152, 1, 1]          56,448
#          Sigmoid-246           [-1, 1152, 1, 1]               0
# SqueezeExcitation-247           [-1, 1152, 7, 7]               0
#           Conv2d-248            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-249            [-1, 192, 7, 7]             384
#  StochasticDepth-250            [-1, 192, 7, 7]               0
#           MBConv-251            [-1, 192, 7, 7]               0
#           Conv2d-252           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-253           [-1, 1152, 7, 7]           2,304
#             SiLU-254           [-1, 1152, 7, 7]               0
#           Conv2d-255           [-1, 1152, 7, 7]          28,800
#      BatchNorm2d-256           [-1, 1152, 7, 7]           2,304
#             SiLU-257           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-258           [-1, 1152, 1, 1]               0
#           Conv2d-259             [-1, 48, 1, 1]          55,344
#             SiLU-260             [-1, 48, 1, 1]               0
#           Conv2d-261           [-1, 1152, 1, 1]          56,448
#          Sigmoid-262           [-1, 1152, 1, 1]               0
# SqueezeExcitation-263           [-1, 1152, 7, 7]               0
#           Conv2d-264            [-1, 192, 7, 7]         221,184
#      BatchNorm2d-265            [-1, 192, 7, 7]             384
#  StochasticDepth-266            [-1, 192, 7, 7]               0
#           MBConv-267            [-1, 192, 7, 7]               0
#           Conv2d-268           [-1, 1152, 7, 7]         221,184
#      BatchNorm2d-269           [-1, 1152, 7, 7]           2,304
#             SiLU-270           [-1, 1152, 7, 7]               0
#           Conv2d-271           [-1, 1152, 7, 7]          10,368
#      BatchNorm2d-272           [-1, 1152, 7, 7]           2,304
#             SiLU-273           [-1, 1152, 7, 7]               0
# AdaptiveAvgPool2d-274           [-1, 1152, 1, 1]               0
#           Conv2d-275             [-1, 48, 1, 1]          55,344
#             SiLU-276             [-1, 48, 1, 1]               0
#           Conv2d-277           [-1, 1152, 1, 1]          56,448
#          Sigmoid-278           [-1, 1152, 1, 1]               0
# SqueezeExcitation-279           [-1, 1152, 7, 7]               0
#           Conv2d-280            [-1, 320, 7, 7]         368,640
#      BatchNorm2d-281            [-1, 320, 7, 7]             640
#           MBConv-282            [-1, 320, 7, 7]               0
#           Conv2d-283           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-284           [-1, 1280, 7, 7]           2,560
#             SiLU-285           [-1, 1280, 7, 7]               0
# AdaptiveAvgPool2d-286           [-1, 1280, 1, 1]               0
#          Dropout-287                 [-1, 1280]               0
#         Identity-288                 [-1, 1280]               0
#     EfficientNet-289                 [-1, 1280]               0
#           Linear-290                 [-1, 1024]       2,360,320
#             ReLU-291                 [-1, 1024]               0
#          Dropout-292                 [-1, 1024]               0
#           Linear-293                   [-1, 38]          38,950
# ================================================================
# Total params: 58,962,242
# Trainable params: 58,962,242
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 317.66
# Params size (MB): 224.92
# Estimated Total Size (MB): 543.15
# ----------------------------------------------------------------

# %% [markdown]
# ### Early Stopping

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0001):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0

    def step(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
            return False  # Do not stop
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True   # Stop training
            return False

early_stopping = EarlyStopping(patience=5, min_delta=0.0001)

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# %%
# Cosine Annealing LR Scheduler
# The learning rate resets every 10 epochs, allowing the model to explore different solutions.
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

current_lr = scheduler.get_last_lr()[0]  # gets the learning rate from the first param group
print(f"Current Learning Rate: {current_lr}")
# Out:
# Current Learning Rate: 0.0001

# %% [markdown]
# ### Batch Gradient Descent / Training Model

# %%
batch_size = 16
train_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=train_sampler, num_workers=2, pin_memory=True
)
test_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=test_sampler, num_workers=2, pin_memory=True
)
validation_loader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, sampler=val_sampler, num_workers=2, pin_memory=True
)
# train_dataset, val_dataset, test_dataset

# %%
def batch_gd(model, criterion, optimizer, scheduler, train_loader, val_loader, epochs):
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        t0 = datetime.now()

        # --- Training Phase ---
        model.train()  # Set model to training mode
        running_train_loss = 0.0

        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()              # Clear gradients from the previous step
            outputs = model(inputs)            # Forward pass
            loss = criterion(outputs, targets) # Compute loss
            loss.backward()                    # Backpropagation
            optimizer.step()                   # Update parameters
            running_train_loss += loss.item()

        avg_train_loss = running_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # --- Validation Phase ---
        model.eval()  # Set model to evaluation mode
        running_val_loss = 0.0

        # Disable gradient computation for validation
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                running_val_loss += loss.item()

        avg_val_loss = running_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        # Step the scheduler based on the validation loss
        scheduler.step()

        # Print epoch statistics
        duration = datetime.now() - t0
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_train_loss:.3f}, Val Loss: {avg_val_loss:.3f}, Duration: {duration}")

        # --- Early Stopping Check ---
        if early_stopping.step(avg_val_loss):
            stopping_epoch = epoch + 1
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    return train_losses, val_losses

# %%
number_of_epoch = 50
train_losses, validation_losses = batch_gd(
    model, criterion, optimizer, scheduler, train_loader, validation_loader, number_of_epoch
)
# Out:
# Epoch 1/50 - Train Loss: 0.953, Val Loss: 0.724, Duration: 0:33:58.980542
# Epoch 2/50 - Train Loss: 0.746, Val Loss: 0.710, Duration: 0:33:58.276630
# Epoch 3/50 - Train Loss: 0.715, Val Loss: 0.697, Duration: 0:33:56.116887
# Epoch 4/50 - Train Loss: 0.704, Val Loss: 0.683, Duration: 0:33:54.139937
# Epoch 5/50 - Train Loss: 0.694, Val Loss: 0.679, Duration: 0:34:06.652281
# Epoch 6/50 - Train Loss: 0.689, Val Loss: 0.679, Duration: 0:33:53.647499
# Epoch 7/50 - Train Loss: 0.686, Val Loss: 0.678, Duration: 0:33:55.706955
# Epoch 8/50 - Train Loss: 0.684, Val Loss: 0.677, Duration: 0:33:52.043267
# Epoch 9/50 - Train Loss: 0.682, Val Loss: 0.677, Duration: 0:33:52.108417
# Epoch 10/50 - Train Loss: 0.681, Val Loss: 0.676, Duration: 0:33:53.006061
# Epoch 11/50 - Train Loss: 0.681, Val Loss: 0.676, Duration: 0:33:56.100386
# Epoch 12/50 - Train Loss: 0.681, Val Loss: 0.675, Duration: 0:33:53.006067
# Epoch 13/50 - Train Loss: 0.681, Val Loss: 0.676, Duration: 0:33:59.867777
# Epoch 14/50 - Train Loss: 0.681, Val Loss: 0.676, Duration: 0:36:49.451251
# Epoch 15/50 - Train Loss: 0.682, Val Loss: 0.678, Duration: 0:34:01.758129
# Epoch 16/50 - Train Loss: 0.683, Val Loss: 0.676, Duration: 0:33:52.030373
# Epoch 17/50 - Train Loss: 0.686, Val Loss: 0.677, Duration: 0:34:07.643899
# Early stopping triggered at epoch 17

# %% [markdown]
# ### Save the Model

# %%
# After training your model:
current_epoch = len(train_losses) 
checkpoint = {
    'model_state_dict': model.state_dict(),
    'train_losses': train_losses,
    'val_losses': validation_losses,
    'epoch': current_epoch
}
torch.save(checkpoint, 'hybrid_model_d04.pt') ## This is the final one

# %% [markdown]
# ### Load Model

# %%
# Reinitialize your model architecture
targets_size = len(dataset.class_to_idx)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HybridModelEfficientNet(targets_size).to(device)

# Load the full checkpoint (includes training history)
full_checkpoint = torch.load("hybrid_model_d04.pt", map_location=device)
model.load_state_dict(full_checkpoint['model_state_dict'])

# Optionally, retrieve training history
train_losses = full_checkpoint.get('train_losses', None)
validation_losses   = full_checkpoint.get('val_losses', None)
epoch        = full_checkpoint.get('epoch', None)

# Set model to evaluation mode
model.eval()

# (Optional) Verify the device of each parameter
for name, param in model.named_parameters():
    print(f"{name} is on {param.device}")
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_22456\1781711896.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   full_checkpoint = torch.load("hybrid_model_d04.pt", map_location=device)
# custom_branch.conv_layers.0.weight is on cuda:0
# custom_branch.conv_layers.0.bias is on cuda:0
# custom_branch.conv_layers.2.weight is on cuda:0
# custom_branch.conv_layers.2.bias is on cuda:0
# custom_branch.conv_layers.3.weight is on cuda:0
# custom_branch.conv_layers.3.bias is on cuda:0
# custom_branch.conv_layers.5.weight is on cuda:0
# custom_branch.conv_layers.5.bias is on cuda:0
# custom_branch.conv_layers.7.weight is on cuda:0
# custom_branch.conv_layers.7.bias is on cuda:0
# custom_branch.conv_layers.9.weight is on cuda:0
# custom_branch.conv_layers.9.bias is on cuda:0
# custom_branch.conv_layers.10.weight is on cuda:0
# custom_branch.conv_layers.10.bias is on cuda:0
# custom_branch.conv_layers.12.weight is on cuda:0
# custom_branch.conv_layers.12.bias is on cuda:0
# custom_branch.conv_layers.14.weight is on cuda:0
# custom_branch.conv_layers.14.bias is on cuda:0
# custom_branch.conv_layers.16.weight is on cuda:0
# custom_branch.conv_layers.16.bias is on cuda:0
# custom_branch.conv_layers.17.weight is on cuda:0
# custom_branch.conv_layers.17.bias is on cuda:0
# custom_branch.conv_layers.19.weight is on cuda:0
# custom_branch.conv_layers.19.bias is on cuda:0
# custom_branch.conv_layers.21.weight is on cuda:0
# custom_branch.conv_layers.21.bias is on cuda:0
# custom_branch.conv_layers.23.weight is on cuda:0
# custom_branch.conv_layers.23.bias is on cuda:0
# custom_branch.conv_layers.24.weight is on cuda:0
# custom_branch.conv_layers.24.bias is on cuda:0
# custom_branch.conv_layers.26.weight is on cuda:0
# custom_branch.conv_layers.26.bias is on cuda:0
# custom_branch.feature_layers.1.weight is on cuda:0
# custom_branch.feature_layers.1.bias is on cuda:0
# pretrained_branch.features.0.0.weight is on cuda:0
# pretrained_branch.features.0.1.weight is on cuda:0
# pretrained_branch.features.0.1.bias is on cuda:0
# pretrained_branch.features.1.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.1.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.1.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.1.0.block.1.fc1.weight is on cuda:0
# pretrained_branch.features.1.0.block.1.fc1.bias is on cuda:0
# pretrained_branch.features.1.0.block.1.fc2.weight is on cuda:0
# pretrained_branch.features.1.0.block.1.fc2.bias is on cuda:0
# pretrained_branch.features.1.0.block.2.0.weight is on cuda:0
# pretrained_branch.features.1.0.block.2.1.weight is on cuda:0
# pretrained_branch.features.1.0.block.2.1.bias is on cuda:0
# pretrained_branch.features.2.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.2.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.2.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.2.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.2.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.2.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.2.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.2.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.2.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.2.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.2.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.2.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.2.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.2.1.block.0.0.weight is on cuda:0
# pretrained_branch.features.2.1.block.0.1.weight is on cuda:0
# pretrained_branch.features.2.1.block.0.1.bias is on cuda:0
# pretrained_branch.features.2.1.block.1.0.weight is on cuda:0
# pretrained_branch.features.2.1.block.1.1.weight is on cuda:0
# pretrained_branch.features.2.1.block.1.1.bias is on cuda:0
# pretrained_branch.features.2.1.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.2.1.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.2.1.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.2.1.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.2.1.block.3.0.weight is on cuda:0
# pretrained_branch.features.2.1.block.3.1.weight is on cuda:0
# pretrained_branch.features.2.1.block.3.1.bias is on cuda:0
# pretrained_branch.features.3.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.3.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.3.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.3.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.3.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.3.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.3.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.3.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.3.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.3.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.3.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.3.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.3.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.3.1.block.0.0.weight is on cuda:0
# pretrained_branch.features.3.1.block.0.1.weight is on cuda:0
# pretrained_branch.features.3.1.block.0.1.bias is on cuda:0
# pretrained_branch.features.3.1.block.1.0.weight is on cuda:0
# pretrained_branch.features.3.1.block.1.1.weight is on cuda:0
# pretrained_branch.features.3.1.block.1.1.bias is on cuda:0
# pretrained_branch.features.3.1.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.3.1.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.3.1.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.3.1.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.3.1.block.3.0.weight is on cuda:0
# pretrained_branch.features.3.1.block.3.1.weight is on cuda:0
# pretrained_branch.features.3.1.block.3.1.bias is on cuda:0
# pretrained_branch.features.4.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.4.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.4.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.4.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.4.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.4.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.4.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.4.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.4.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.4.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.4.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.4.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.4.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.4.1.block.0.0.weight is on cuda:0
# pretrained_branch.features.4.1.block.0.1.weight is on cuda:0
# pretrained_branch.features.4.1.block.0.1.bias is on cuda:0
# pretrained_branch.features.4.1.block.1.0.weight is on cuda:0
# pretrained_branch.features.4.1.block.1.1.weight is on cuda:0
# pretrained_branch.features.4.1.block.1.1.bias is on cuda:0
# pretrained_branch.features.4.1.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.4.1.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.4.1.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.4.1.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.4.1.block.3.0.weight is on cuda:0
# pretrained_branch.features.4.1.block.3.1.weight is on cuda:0
# pretrained_branch.features.4.1.block.3.1.bias is on cuda:0
# pretrained_branch.features.4.2.block.0.0.weight is on cuda:0
# pretrained_branch.features.4.2.block.0.1.weight is on cuda:0
# pretrained_branch.features.4.2.block.0.1.bias is on cuda:0
# pretrained_branch.features.4.2.block.1.0.weight is on cuda:0
# pretrained_branch.features.4.2.block.1.1.weight is on cuda:0
# pretrained_branch.features.4.2.block.1.1.bias is on cuda:0
# pretrained_branch.features.4.2.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.4.2.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.4.2.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.4.2.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.4.2.block.3.0.weight is on cuda:0
# pretrained_branch.features.4.2.block.3.1.weight is on cuda:0
# pretrained_branch.features.4.2.block.3.1.bias is on cuda:0
# pretrained_branch.features.5.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.5.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.5.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.5.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.5.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.5.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.5.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.5.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.5.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.5.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.5.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.5.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.5.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.5.1.block.0.0.weight is on cuda:0
# pretrained_branch.features.5.1.block.0.1.weight is on cuda:0
# pretrained_branch.features.5.1.block.0.1.bias is on cuda:0
# pretrained_branch.features.5.1.block.1.0.weight is on cuda:0
# pretrained_branch.features.5.1.block.1.1.weight is on cuda:0
# pretrained_branch.features.5.1.block.1.1.bias is on cuda:0
# pretrained_branch.features.5.1.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.5.1.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.5.1.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.5.1.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.5.1.block.3.0.weight is on cuda:0
# pretrained_branch.features.5.1.block.3.1.weight is on cuda:0
# pretrained_branch.features.5.1.block.3.1.bias is on cuda:0
# pretrained_branch.features.5.2.block.0.0.weight is on cuda:0
# pretrained_branch.features.5.2.block.0.1.weight is on cuda:0
# pretrained_branch.features.5.2.block.0.1.bias is on cuda:0
# pretrained_branch.features.5.2.block.1.0.weight is on cuda:0
# pretrained_branch.features.5.2.block.1.1.weight is on cuda:0
# pretrained_branch.features.5.2.block.1.1.bias is on cuda:0
# pretrained_branch.features.5.2.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.5.2.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.5.2.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.5.2.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.5.2.block.3.0.weight is on cuda:0
# pretrained_branch.features.5.2.block.3.1.weight is on cuda:0
# pretrained_branch.features.5.2.block.3.1.bias is on cuda:0
# pretrained_branch.features.6.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.6.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.6.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.6.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.6.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.6.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.6.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.6.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.6.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.6.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.6.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.6.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.6.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.6.1.block.0.0.weight is on cuda:0
# pretrained_branch.features.6.1.block.0.1.weight is on cuda:0
# pretrained_branch.features.6.1.block.0.1.bias is on cuda:0
# pretrained_branch.features.6.1.block.1.0.weight is on cuda:0
# pretrained_branch.features.6.1.block.1.1.weight is on cuda:0
# pretrained_branch.features.6.1.block.1.1.bias is on cuda:0
# pretrained_branch.features.6.1.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.6.1.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.6.1.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.6.1.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.6.1.block.3.0.weight is on cuda:0
# pretrained_branch.features.6.1.block.3.1.weight is on cuda:0
# pretrained_branch.features.6.1.block.3.1.bias is on cuda:0
# pretrained_branch.features.6.2.block.0.0.weight is on cuda:0
# pretrained_branch.features.6.2.block.0.1.weight is on cuda:0
# pretrained_branch.features.6.2.block.0.1.bias is on cuda:0
# pretrained_branch.features.6.2.block.1.0.weight is on cuda:0
# pretrained_branch.features.6.2.block.1.1.weight is on cuda:0
# pretrained_branch.features.6.2.block.1.1.bias is on cuda:0
# pretrained_branch.features.6.2.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.6.2.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.6.2.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.6.2.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.6.2.block.3.0.weight is on cuda:0
# pretrained_branch.features.6.2.block.3.1.weight is on cuda:0
# pretrained_branch.features.6.2.block.3.1.bias is on cuda:0
# pretrained_branch.features.6.3.block.0.0.weight is on cuda:0
# pretrained_branch.features.6.3.block.0.1.weight is on cuda:0
# pretrained_branch.features.6.3.block.0.1.bias is on cuda:0
# pretrained_branch.features.6.3.block.1.0.weight is on cuda:0
# pretrained_branch.features.6.3.block.1.1.weight is on cuda:0
# pretrained_branch.features.6.3.block.1.1.bias is on cuda:0
# pretrained_branch.features.6.3.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.6.3.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.6.3.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.6.3.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.6.3.block.3.0.weight is on cuda:0
# pretrained_branch.features.6.3.block.3.1.weight is on cuda:0
# pretrained_branch.features.6.3.block.3.1.bias is on cuda:0
# pretrained_branch.features.7.0.block.0.0.weight is on cuda:0
# pretrained_branch.features.7.0.block.0.1.weight is on cuda:0
# pretrained_branch.features.7.0.block.0.1.bias is on cuda:0
# pretrained_branch.features.7.0.block.1.0.weight is on cuda:0
# pretrained_branch.features.7.0.block.1.1.weight is on cuda:0
# pretrained_branch.features.7.0.block.1.1.bias is on cuda:0
# pretrained_branch.features.7.0.block.2.fc1.weight is on cuda:0
# pretrained_branch.features.7.0.block.2.fc1.bias is on cuda:0
# pretrained_branch.features.7.0.block.2.fc2.weight is on cuda:0
# pretrained_branch.features.7.0.block.2.fc2.bias is on cuda:0
# pretrained_branch.features.7.0.block.3.0.weight is on cuda:0
# pretrained_branch.features.7.0.block.3.1.weight is on cuda:0
# pretrained_branch.features.7.0.block.3.1.bias is on cuda:0
# pretrained_branch.features.8.0.weight is on cuda:0
# pretrained_branch.features.8.1.weight is on cuda:0
# pretrained_branch.features.8.1.bias is on cuda:0
# fusion.0.weight is on cuda:0
# fusion.0.bias is on cuda:0
# fusion.3.weight is on cuda:0
# fusion.3.bias is on cuda:0

# %% [markdown]
# ### Plot the loss

# %%
import matplotlib.pyplot as plt

def plot_learning_curve(train_losses, validation_losses):
    epochs = range(1, len(train_losses) + 1)
    
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_losses, 'bo-', label='Training Loss')
    plt.plot(epochs, validation_losses, 'ro-', label='Validation Loss')
    
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# After your training loop finishes and you have train_losses and validation_losses:
plot_learning_curve(train_losses, validation_losses)

# %%
plt.plot(train_losses , label = 'train_loss')
plt.plot(validation_losses , label = 'validation_loss')
plt.xticks(range(1, len(train_losses) + 1))
plt.xlabel('No of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Accuracy

# %%
from tabulate import tabulate  # pip install tabulate

def accuracy(loader, model, device):
    # Set model to evaluation mode
    model.eval()
    
    # Initialize counters
    n_correct = 0
    n_total = 0
    num_classes = len(loader.dataset.classes)
    correct_per_class = np.zeros(num_classes)
    total_per_class = np.zeros(num_classes)
    
    # Disable gradient computation
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            # Update overall counters
            n_correct += (predictions == targets).sum().item()
            n_total += targets.size(0)
            
            # Update per-class counters
            for i in range(num_classes):
                correct_per_class[i] += ((predictions == i) & (targets == i)).sum().item()
                total_per_class[i] += (targets == i).sum().item()
    
    # Calculate overall accuracy
    overall_accuracy = n_correct / n_total
    
    # Calculate per-class accuracy
    per_class_accuracy = correct_per_class / total_per_class
    per_class_accuracy = np.nan_to_num(per_class_accuracy)  # Handle division by zero
    
    # Create table data using tabulate
    table_data = []
    for i, class_name in enumerate(loader.dataset.classes):
        table_data.append([class_name, f"{per_class_accuracy[i] * 100:.2f}"])
    
    print("\nPer-Class Accuracy:")
    print(tabulate(table_data, headers=["Category", "Accuracy (%)"], tablefmt="github"))
    
    return overall_accuracy, per_class_accuracy

# %%
train_overall_acc, per_class_acc = accuracy(train_loader, model, device)
print(f"Overall Training Accuracy: {train_overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                           |   Accuracy (%) |
# |----------------------------------------------------|----------------|
# | Apple___Apple_scab                                 |         100    |
# | Apple___Black_rot                                  |         100    |
# | Apple___Cedar_apple_rust                           |         100    |
# | Apple___healthy                                    |         100    |
# | Blueberry___healthy                                |         100    |
# | Cherry_(including_sour)___Powdery_mildew           |         100    |
# | Cherry_(including_sour)___healthy                  |         100    |
# | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |         100    |
# | Corn_(maize)___Common_rust_                        |         100    |
# | Corn_(maize)___Northern_Leaf_Blight                |          99.95 |
# | Corn_(maize)___healthy                             |         100    |
# | Grape___Black_rot                                  |         100    |
# | Grape___Esca_(Black_Measles)                       |         100    |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)         |         100    |
# | Grape___healthy                                    |         100    |
# | Orange___Haunglongbing_(Citrus_greening)           |         100    |
# | Peach___Bacterial_spot                             |         100    |
# | Peach___healthy                                    |         100    |
# | Pepper,_bell___Bacterial_spot                      |         100    |
# | Pepper,_bell___healthy                             |         100    |
# | Potato___Early_blight                              |         100    |
# | Potato___Late_blight                               |         100    |
# | Potato___healthy                                   |         100    |
# | Raspberry___healthy                                |         100    |
# | Soybean___healthy                                  |         100    |
# | Squash___Powdery_mildew                            |         100    |
# | Strawberry___Leaf_scorch                           |         100    |
# | Strawberry___healthy                               |         100    |
# | Tomato___Bacterial_spot                            |         100    |
# | Tomato___Early_blight                              |         100    |
# | Tomato___Late_blight                               |         100    |
# | Tomato___Leaf_Mold                                 |         100    |
# | Tomato___Septoria_leaf_spot                        |          99.89 |
# | Tomato___Spider_mites Two-spotted_spider_mite      |          99.95 |
# | Tomato___Target_Spot                               |          99.89 |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus             |         100    |
# | Tomato___Tomato_mosaic_virus                       |         100    |
# | Tomato___healthy                                   |         100    |
# Overall Training Accuracy: 0.9999

# %%
val_overall_acc, per_class_acc = accuracy(validation_loader, model, device)
print(f"Overall Validation Accuracy: {val_overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                           |   Accuracy (%) |
# |----------------------------------------------------|----------------|
# | Apple___Apple_scab                                 |         100    |
# | Apple___Black_rot                                  |         100    |
# | Apple___Cedar_apple_rust                           |         100    |
# | Apple___healthy                                    |         100    |
# | Blueberry___healthy                                |         100    |
# | Cherry_(including_sour)___Powdery_mildew           |         100    |
# | Cherry_(including_sour)___healthy                  |         100    |
# | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |          99.13 |
# | Corn_(maize)___Common_rust_                        |          99.13 |
# | Corn_(maize)___Northern_Leaf_Blight                |          99.57 |
# | Corn_(maize)___healthy                             |         100    |
# | Grape___Black_rot                                  |         100    |
# | Grape___Esca_(Black_Measles)                       |         100    |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)         |         100    |
# | Grape___healthy                                    |         100    |
# | Orange___Haunglongbing_(Citrus_greening)           |         100    |
# | Peach___Bacterial_spot                             |         100    |
# | Peach___healthy                                    |         100    |
# | Pepper,_bell___Bacterial_spot                      |         100    |
# | Pepper,_bell___healthy                             |         100    |
# | Potato___Early_blight                              |         100    |
# | Potato___Late_blight                               |         100    |
# | Potato___healthy                                   |         100    |
# | Raspberry___healthy                                |         100    |
# | Soybean___healthy                                  |         100    |
# | Squash___Powdery_mildew                            |         100    |
# | Strawberry___Leaf_scorch                           |         100    |
# | Strawberry___healthy                               |         100    |
# | Tomato___Bacterial_spot                            |          99.13 |
# | Tomato___Early_blight                              |          99.57 |
# | Tomato___Late_blight                               |          99.57 |
# | Tomato___Leaf_Mold                                 |         100    |
# | Tomato___Septoria_leaf_spot                        |         100    |
# | Tomato___Spider_mites Two-spotted_spider_mite      |         100    |
# | Tomato___Target_Spot                               |          99.13 |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus             |         100    |
# | Tomato___Tomato_mosaic_virus                       |         100    |
# | Tomato___healthy                                   |         100    |
# Overall Validation Accuracy: 0.9987

# %%
overall_acc, per_class_acc = accuracy(test_loader, model, device)
print(f"Overall Test Accuracy: {overall_acc:.4f}\n")
# Out:
# Per-Class Accuracy:
# | Category                                           |   Accuracy (%) |
# |----------------------------------------------------|----------------|
# | Apple___Apple_scab                                 |         100    |
# | Apple___Black_rot                                  |         100    |
# | Apple___Cedar_apple_rust                           |         100    |
# | Apple___healthy                                    |         100    |
# | Blueberry___healthy                                |         100    |
# | Cherry_(including_sour)___Powdery_mildew           |         100    |
# | Cherry_(including_sour)___healthy                  |         100    |
# | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |          99.57 |
# | Corn_(maize)___Common_rust_                        |         100    |
# | Corn_(maize)___Northern_Leaf_Blight                |          99.13 |
# | Corn_(maize)___healthy                             |         100    |
# | Grape___Black_rot                                  |         100    |
# | Grape___Esca_(Black_Measles)                       |         100    |
# | Grape___Leaf_blight_(Isariopsis_Leaf_Spot)         |         100    |
# | Grape___healthy                                    |         100    |
# | Orange___Haunglongbing_(Citrus_greening)           |         100    |
# | Peach___Bacterial_spot                             |         100    |
# | Peach___healthy                                    |         100    |
# | Pepper,_bell___Bacterial_spot                      |         100    |
# | Pepper,_bell___healthy                             |          99.57 |
# | Potato___Early_blight                              |         100    |
# | Potato___Late_blight                               |         100    |
# | Potato___healthy                                   |         100    |
# | Raspberry___healthy                                |         100    |
# | Soybean___healthy                                  |         100    |
# | Squash___Powdery_mildew                            |         100    |
# | Strawberry___Leaf_scorch                           |         100    |
# | Strawberry___healthy                               |         100    |
# | Tomato___Bacterial_spot                            |         100    |
# | Tomato___Early_blight                              |         100    |
# | Tomato___Late_blight                               |          99.57 |
# | Tomato___Leaf_Mold                                 |         100    |
# | Tomato___Septoria_leaf_spot                        |          98.7  |
# | Tomato___Spider_mites Two-spotted_spider_mite      |         100    |
# | Tomato___Target_Spot                               |          99.13 |
# | Tomato___Tomato_Yellow_Leaf_Curl_Virus             |          99.57 |
# | Tomato___Tomato_mosaic_virus                       |         100    |
# | Tomato___healthy                                   |         100    |
# Overall Test Accuracy: 0.9987

# %%
print(
    f"Train Accuracy : {train_overall_acc} \nTest Accuracy : {overall_acc}\nValidation Accuracy : {val_overall_acc}"
)
# Out:
# Train Accuracy : 0.9999141876430206
# Test Accuracy : 0.9987414187643021
# Validation Accuracy : 0.9987414187643021

# %% [markdown]
# ### Precision, Recall and F1-score

# %%
import pandas as pd
from sklearn.metrics import classification_report

def evaluate_metrics(loader):
    y_true = []
    y_pred = []

    # Ensure model is in eval mode and disable gradients
    model.eval()
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())
    
    # Get the report as a dictionary
    report_dict = classification_report(y_true, y_pred, target_names=dataset.classes, output_dict=True)
    
    # Convert dictionary to a Pandas DataFrame and transpose it so that each row is a class.
    report_df = pd.DataFrame(report_dict).transpose()
    return report_df

# Calculate metrics for each set
train_report = evaluate_metrics(train_loader)
validation_report = evaluate_metrics(validation_loader)
test_report = evaluate_metrics(test_loader)

# %%
# Write the reports to an Excel file with multiple sheets
excel_filename = "metrics_hybrid_model_d04.xlsx"
with pd.ExcelWriter(excel_filename) as writer:
    train_report.to_excel(writer, sheet_name="train")
    validation_report.to_excel(writer, sheet_name="validation")
    test_report.to_excel(writer, sheet_name="test")

print(f"Metrics saved to {excel_filename}")
# Out:
# Metrics saved to metrics_hybrid_model_d04.xlsx

# %% [markdown]
# ### Confusion Matrix

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_confusion_matrix(loader):
    y_true = []
    y_pred = []
    
    # Ensure the model is in evaluation mode
    model.eval()
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            
            y_true.extend(targets.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Convert to a DataFrame for better labeling
    cm_df = pd.DataFrame(cm, index=dataset.classes, columns=dataset.classes)
    return cm_df

def plot_confusion_matrix(cm_df, title="Confusion Matrix"):
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=True, annot_kws={"size": 8})
    plt.title(title, fontsize=18)
    plt.ylabel("Actual", fontsize=14)
    plt.xlabel("Predicted", fontsize=14)
    plt.show()

# %%
# Evaluate confusion matrices for train, validation, and test sets
cm_train = evaluate_confusion_matrix(train_loader)
cm_val = evaluate_confusion_matrix(validation_loader)
cm_test = evaluate_confusion_matrix(test_loader)

# %%
# Plot the confusion matrices
plot_confusion_matrix(cm_train, title="Train Confusion Matrix")
plot_confusion_matrix(cm_val, title="Validation Confusion Matrix")
plot_confusion_matrix(cm_test, title="Test Confusion Matrix")
